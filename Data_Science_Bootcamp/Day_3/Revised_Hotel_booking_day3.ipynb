# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # We assign the excel file to variable hb

# %%
hb= pd.read_excel("/content/hotel_bookings.xlsx")
hb.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type adr  \
# 0    NaN     NaN                    0     Transient   0
# 1    NaN     NaN                    0     Transient   0
# 2    NaN     NaN                    0     Transient  75
# 3  304.0     NaN                    0     Transient  75
# 4  240.0     NaN                    0     Transient  98
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %% [markdown]
# # Preprocessing data

# %%
sns.heatmap(hb.isnull(), yticklabels=False , cbar=False , cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# **We decided to delete columnn "company" because NULL values are a majority**

# %%
hb.drop("company",axis=1, inplace =True)

# %%
sns.heatmap(hb.isnull(), yticklabels=False , cbar=False , cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# **Now we convert NULL values in Agent to 0**

# %%
hb['agent'] = hb['agent'].fillna(0)

# %%
sns.heatmap(hb.isnull(), yticklabels=False , cbar=False , cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# **Now we change agent column to string type**

# %%
hb['agent'] = hb['agent'].astype(str)

# %%
sns.heatmap(hb.isnull(), yticklabels=False , cbar=False , cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# **We delete the remaining NULL value given that it's only one and does not affect the dataset when deleted**

# %%
hb.dropna(inplace=True)

# %%
sns.heatmap(hb.isnull(), yticklabels=False , cbar=False , cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# **Encoding "reservation statues", First column "Check-out" -> If True then customer checked out, if False customer canceled.
# Second column named "No-show", if both "Check-out" and "Customer-cancel" are false, then that means the customer is a no-show**

# %%
resStatus = pd.get_dummies(hb['reservation_status'], drop_first = True)
hb = pd.concat([hb, resStatus], axis = 1)

# %%
hb.drop('reservation_status', axis=1, inplace = True)

# %%
hb.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent days_in_waiting_list customer_type adr required_car_parking_spaces  \
# 0    0.0                    0     Transient   0                           0
# 1    0.0                    0     Transient   0                           0
# 2    0.0                    0     Transient  75                           0
# 3  304.0                    0     Transient  75                           0
# 4  240.0                    0     Transient  98                           0
#
#    total_of_special_requests  reservation_status_date  Check-Out No-Show
# 0                          0               2015-07-01       True   False
# 1                          0               2015-07-01       True   False
# 2                          0               2015-07-02       True   False
# 3                          0               2015-07-02       True   False
# 4                          1               2015-07-03       True   False
#
# [5 rows x 32 columns]

# %%
correlation = hb.corr(numeric_only=True)

plt.figure(figsize=(20,12))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# **This scatterplot chart compares the correlation between Week night stays and weekend, it shows that there is a linear correlation between the two, and we can also conclude that a lot of customers who book a  extend their reservation**

# %%
plt.scatter(hb['stays_in_weekend_nights'], hb['stays_in_week_nights'])
plt.xlabel("weekend night")
plt.ylabel("week night")
plt.title("Correlation between week and weekend reservation")
plt.show()

# %%
hb['is_repeated_guest'].value_counts().plot(kind='bar')

plt.xlabel("Is Repeated Guest (0 = No, 1 = Yes)")
plt.ylabel("Canceled bookings")
plt.title("Number of Repeated vs Non-Repeated Guests")
plt.show()

# %% [markdown]
# **We conclude that the majority of people that canceled are not repeated guests**
